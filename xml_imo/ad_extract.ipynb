# %%
from xml.dom import minidom

with open("XML-IMO.xml", 'r', encoding='utf-8') as f:
    xml = minidom.parse(f)
    anuncios = xml.getElementsByTagName("Listing")
    local = [
        xml.getElementsByTagName("Country"),
        xml.getElementsByTagName("State"),
        xml.getElementsByTagName("City"),
        xml.getElementsByTagName("Neighborhood"),
        xml.getElementsByTagName("PostalCode"),
        xml.getElementsByTagName("Address"),
    ]

    for count, element in enumerate(local[0]):
        print(f"\n Pais: {local[0][count].firstChild.data}",
              f"\n Estado: {local[1][count].firstChild.data}",
              f"\n Cidade: {local[2][count].firstChild.data}",
              f"\n Bairro: {local[3][count].firstChild.data}",
              f"\n CEP: {local[4][count].firstChild.data}",
              f"\n Rua/Endereco: {local[5][count].firstChild.data}",
              f"\n {count}"
              )
# Out:
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Caieiras
#  Bairro: Vera Tereza
#  CEP: 07718025
#  Rua/Endereco: RUA JOSÉ FAILLACE (Bairro Vila dos Pinheiros)
#  0
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Caieiras
#  Bairro: Vera Tereza
#  CEP: 07718025
#  Rua/Endereco: Rua Cuiabá
#  1
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Lanfranki
#  CEP: 07861120
#  Rua/Endereco: Rua Guadalajara, Lote 37 A, Quadra: O, Loteamento Jardim Santo Antônio
#  2
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Lanfranki
#  CEP: 07861120
#  Rua/Endereco: RUA JOAQUIM DUARTE MACHADO
#  3
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Caieiras
#  Bairro: Centro
#  CEP: 07700360
#  Rua/Endereco: RUA RECIFE
#  4
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Caieiras
#  Bairro: Centro
#  CEP: 07700360
#  Rua/Endereco: Rua Das Orquídeas
#  5
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Bazu
#  CEP: 07807020
#  Rua/Endereco: ESTRADA MANOEL DE JESUS, BLOCO E - APTO 32 CONDOMÍNIO AROEIRAS
#  6
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Bazu
#  CEP: 07807020
#  Rua/Endereco: ESTRADA MANOEL DE JESUS, BLOCO E - APTO 32 - 3° ANDAR
#  7
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Parque Monte Verde
#  CEP: 07861160
#  Rua/Endereco: ESTRADA MANOEL DE JESUS - SÍTIO CATUÍ
#  8
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Parque Monte Verde
#  CEP: 07861160
#  Rua/Endereco: ESTRADA MANOEL DE JESUS, APTO 31, BLOCO A, 3°ANDAR - CONDOMÍNIO FIGUEIRAS
#  9
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Belmiro
#  CEP: 07809210
#  Rua/Endereco: RUA EMILE ZOLA
#  10
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Belmiro
#  CEP: 07809210
#  Rua/Endereco: Rua Alberto Federzoni, 702
#  11
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: Rua Alberto Federzoni, 702
#  12
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: Rua Alberto Federzoni, 702
#  13
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: Rua Alberto Federzoni, 702
#  14
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: Rua Alberto Federzoni, 702
#  15
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: RUA TEÓFILA VANDERLINDE, 167 - APTO 67 - 6° ANDAR - VILA ALICE - RESIDENCIAL ANTONIO S.
#                     GASPAR
#
#  16
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: ESTRADA MANOEL DE JESUS - 3° ANDAR
#  17
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: RUA HIMALAIA - QUADRA 10
#  18
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Vila Palmares
#  CEP: 07863005
#  Rua/Endereco: Avenida Dr. Franco da Rocha
#  19
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Parque Monte Verde
#  CEP: 07862020
#  Rua/Endereco: Estrada Otávio Della Torre
#  20
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Parque Monte Verde
#  CEP: 07862020
#  Rua/Endereco: RUA SÃO ROQUE - CASA FUNDOS (VERDE)
#  21
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA SÃO ROQUE - CASA FUNDOS (LARANJA)
#  22
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA SÃO ROQUE - CASA AMARELA (DA FRENTE)
#  23
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA SÃO ROQUE - CASA FUNDOS (LARANJA)
#  24
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA SÃO ROQUE - CASA VERMELHA (DA FRENTE)
#  25
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA SÃO ROQUE - CASA DO MEIO (AZUL)
#  26
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA LEONILDA BALDIM
#  27
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: ________
#  Rua/Endereco: Rua Hortencia Pinto Zomignan (Jd dos Abreus I) CASA 01
#  28
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: ________
#  Rua/Endereco: RUA DANIEL CÂNDIDO DOS SANTOS
#  29
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA VINTE E DOIS
#  30
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Jardim Benintendi
#  CEP: 07851050
#  Rua/Endereco: RUA VINTE E DOIS
#  31
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Praia Grande
#  Bairro: Ocian
#  CEP: 11704460
#  Rua/Endereco: RUA VINTE E DOIS
#  32
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Praia Grande
#  Bairro: Ocian
#  CEP: 11704460
#  Rua/Endereco: Avenida Arco Iris
#  33
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Chácaras São José
#  CEP: 07863420
#  Rua/Endereco: Avenida Ouro Branco
#  34
#
#  Pais: Brasil
#  Estado: São Paulo
#  Cidade: Franco da Rocha
#  Bairro: Chácaras São José
#  CEP: 07863420
#  Rua/Endereco: RUA HIMALAIA - QUADRA 10
#  35
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 20
#       6 local = [
#       7     xml.getElementsByTagName("Country"),
#       8     xml.getElementsByTagName("State"),
#    (...)
#      12     xml.getElementsByTagName("Address"),
#      13 ]
#      15 for count, element in enumerate(local[0]):
#      16     print(f"\n Pais: {local[0][count].firstChild.data}",
#      17           f"\n Estado: {local[1][count].firstChild.data}",
#      18           f"\n Cidade: {local[2][count].firstChild.data}",
#      19           f"\n Bairro: {local[3][count].firstChild.data}",
# ---> 20           f"\n CEP: {local[4][count].firstChild.data}",
#      21           f"\n Rua/Endereco: {local[5][count].firstChild.data}",
#      22           f"\n {count}"
#      23           )
#
# AttributeError: 'NoneType' object has no attribute 'data'
